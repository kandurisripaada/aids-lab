# %%
import pandas as pd
import random
import numpy as np
import matplotlib.pyplot as plt

random.seed(42)
data = {
    'weight': [random.randint(50, 100) for _ in range(15)],  
    'height': [random.randint(150, 180) for _ in range(15)]
}
df = pd.DataFrame(data)
print(df)
df.to_csv("weight_height_dataset.csv", index=False)
# Out:
#     weight  height
# 0       90     163
# 1       57     151
# 2       51     150
# 3       97     152
# 4       67     156
# 5       65     157
# 6       64     166
# 7       58     169
# 8       97     150
# 9       56     167
# 10      93     156
# 11      97     172
# 12      84     170
# 13      55     172
# 14      87     167

# %%
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   weight  15 non-null     int64
#  1   height  15 non-null     int64
# dtypes: int64(2)
# memory usage: 372.0 bytes
# weight    0
# height    0
# dtype: int64

# %%
import seaborn as sns
sns.scatterplot(df)
# Out:
# <Axes: >

# %%
sns.pairplot(df)
# Out:
# C:\Users\CVR\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df=pd.read_csv('demo.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   weight  16 non-null     int64
#  1   height  16 non-null     int64
# dtypes: int64(2)
# memory usage: 388.0 bytes

# %%
df.head(5)
# Out:
#    weight  height
# 0      30     160
# 1      32     161
# 2      34     162
# 3      35     150
# 4      36     172

# %%
##Scatter plot

plt.scatter(df['weight'], df['height'])

plt.xlabel("Weight (kg)")

plt.ylabel("Height (cm)")

plt.title("Scatter Plot of Weight vs Height")

plt.show()

# %%
sns.pairplot(df)
# Out:
# C:\Users\CVR\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Independent feature
x=df['weight']
type(x)
# Out:
# pandas.core.series.Series

# %%
x=df[['weight']]
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
#Dependent feature
y=df['height']
type(y)
# Out:
# pandas.core.series.Series

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30,random_state=42)
print(y_train)
print(y_test)
# Out:
# 11    189
# 8     145
# 9     150
# 2     162
# 15    180
# 4     172
# 7     156
# 10    167
# 12    177
# 3     150
# 6     182
# Name: height, dtype: int64
# 0     160
# 1     161
# 5     180
# 14    178
# 13    170
# Name: height, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)
x_test_scaled
# Out:
# C:\Users\CVR\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-5.18135808],
#        [-5.17945651],
#        [-5.1718502 ],
#        [-5.12621236],
#        [-5.13381867]])

# %%
x_test = scaler.transform(x_test)
x_test
# Out:
# C:\Users\CVR\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-5.18135808],
#        [-5.17945651],
#        [-5.1718502 ],
#        [-5.12621236],
#        [-5.13381867]])

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression(n_jobs=-1)
